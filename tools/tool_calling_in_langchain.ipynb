# %% [markdown]
# <a href="https://colab.research.google.com/github/PujanPandey07/LangChain/blob/main/tools/tool_calling_in_langchain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.environ['GOOGLE_API_KEY']='AIzaSyCIEIPxCZ0GN3o1ePH7i3TxXy5n37Pef70'

# %%
# !pip install -q langchain-google_genai langchain-core requests
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 4.8 MB/s eta 0:00:00

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.tools import tool
from langchain_core.messages import HumanMessage
import requests

# %%
@tool
def multiply(a: int, b: int) -> int:
    """Multiplies two integers and returns the result."""
    return a * b

# %%
print(multiply.invoke({"a": 2, "b": 3}))
# Out:
# 6

# %%
multiply.name
# Out:
# 'multiply'

# %%
multiply.description
# Out:
# 'Multiplies two integers and returns the result.'

# %%
multiply.args
# Out:
# {'a': {'title': 'A', 'type': 'integer'},
#  'b': {'title': 'B', 'type': 'integer'}}

# %%
#tool binding
llm=ChatGoogleGenerativeAI(model='models/gemini-2.5-flash',api_key=os.getenv('GOOGLE_API_KEY'))

# %%
llm_with_tools=llm.bind_tools([multiply])

# %%
llm_with_tools.invoke('Hi how are you')
# Out:
# AIMessage(content="I'm doing well, thank you! How can I help you today?", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019edaab-6b02-7b72-babd-2bba955eb710-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 56, 'output_tokens': 16, 'total_tokens': 72, 'input_token_details': {'cache_read': 0}})

# %%
query = HumanMessage('can you multiply 3 with 1000')

# %%
messages = [query]

# %%
result = llm_with_tools.invoke(messages)

# %%
result
# Out:
# AIMessage(content='', additional_kwargs={'function_call': {'name': 'multiply', 'arguments': '{"b": 1000, "a": 3}'}, '__gemini_function_call_thought_signatures__': {'f33e7a60-ccc5-4ce9-b593-89d43da6ee40': ''}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019edaad-cb68-7a31-a5ce-e4493929b263-0', tool_calls=[{'name': 'multiply', 'args': {'b': 1000, 'a': 3}, 'id': 'f33e7a60-ccc5-4ce9-b593-89d43da6ee40', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 63, 'output_tokens': 92, 'total_tokens': 155, 
# ...

# %%
messages.append(result)

# %%
messages
# Out:
# [HumanMessage(content='can you multiply 3 with 1000', additional_kwargs={}, response_metadata={}),
# ...

# %%
tool_result = multiply.invoke(result.tool_calls[0])

# %%
tool_result
# Out:
# ToolMessage(content='3000', name='multiply', tool_call_id='f33e7a60-ccc5-4ce9-b593-89d43da6ee40')

# %%
messages.append(tool_result)

# %%
messages
# Out:
# [HumanMessage(content='can you multiply 3 with 1000', additional_kwargs={}, response_metadata={}),
# ...

# %%
llm_with_tools.invoke(messages).content
# Out:
# 'The answer is 3000.'
